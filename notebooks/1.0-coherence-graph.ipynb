# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /Users/mac/miniforge3/envs/phd/lib/python3.8/site-packages (2.8.8)

# %%
# Run if working locally
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sqlite3
from sqlite3 import Error
import pickle
import os, sys
import config

config.root_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, config.root_path)

from src.dataset.dataset import RawData
from src.dataset.wikisection_preprocessing import (
    tokenize,
    clean_sentence,
    preprocess_text_segmentation,
    format_data_for_db_insertion,
)
from src.dataset.utils import truncate_by_token
from db.dbv2 import Table, AugmentedTable, TrainTestTable
import pprint


from utils.metrics import windowdiff, pk
import networkx as nx

# %%
dataset_type = "city"
table = Table(dataset_type)
# Out:
# Using dataset: wikisection_city

# %%
import networkx as nx
import matplotlib.pyplot as plt
# >>> G = nx.Graph()
# >>> G.add_edge("A", "B", weight=4)
# >>> G.add_edge("B", "D", weight=2)
# >>> G.add_edge("A", "C", weight=3)
# >>> G.add_edge("C", "D", weight=4)
# >>> nx.shortest_path(G, "A", "D", weight="weight")

class CoherenceGraph(nx.Graph):
    def __init__(self):
        nx.Graph.__init__(self)

    # overriden function to add more functionality to the traditional add_edge function
    def add_edge(self, *args, **kwargs):
        super().add_edge(*args, **kwargs)

    # get a node based on an id
    def get_node_by_id(self, id: str):
        for n, nbrs in G.adj.items():
            if n.id == id:
                return (n, nbrs)
        return None

    # get a node based on a word
    def get_node(self, word: str):
        for n, nbrs in G.adj.items():
            if n.word == word:
                return (n, nbrs)
        return None

    # remove all nodes that don't have any edges
    def prune_isolated_nodes(self):
        isolated_nodes = list(nx.isolates(self))
        self.remove_nodes_from(list(nx.isolates(self)))
        return isolated_nodes

    # remove all nodes beyond the max_depth
    def prune_max_depth(self, max_depth: int, current_node: CoherenceNode):
        pruned_nodes = []
        for n, nbrs in G.adj.items():
            try:
                if nx.shortest_path_length(G, source=n, target=current_node) >= max_depth:
                    pruned_nodes.append(n)
            except:
                # no shortest path could be found - node is isolated
                pass

        self.remove_nodes_from(list(pruned_nodes))
        return pruned_nodes

    # we want to get all the nodes that have some pathway to the current node
    # so we can gather all the cohesive words and make a word compilation vector.
    def get_all_paths_to_node(self, current_node: CoherenceNode):
        paths = []
        for n in self.nodes():
            for path in nx.all_simple_paths(G, source=current_node, target=n):
                paths.append(path)
        return paths


class CoherenceNode():
    def __init__(self, id, word, vector):
        self.id = id
        self.word = word
        self.vector = vector
        # self.distance = distance
        # self.level = level
    
    def __repr__(self):
        return f'Node({self.id}, \'{self.word}\', {self.vector})'
        
    def __str__(self):
        return f'Node(\'{self.word}\')'

# %%
G = CoherenceGraph()

# %%
# (id, word_text, vector_representation)

segments = [
    [(0, "hello", 5), (1, "world", 6), (2, "earth", 7)],
    [(3, "school", 3), (4, "work", 5)],
    [(5, "assignments", 6), (6, "deadline", 4), (7, "lazy", 2), (8, "midterms", 5)],
    [(9, "gym", 4.5), (10, "math", 6), (11, "science", 6.5), (12, "world", 2)],
]

# %%
# simulation

temp_prev_graph = nx.Graph()
for segment in segments:
    # create a previous graph to hold all the words from the previous sentence
    # such that we can only compare the current words with the previous sentence
    prev_graph = temp_prev_graph
    temp_prev_graph = nx.Graph()
    for word in segment:
        # create a temp graph to hold the edges, which we'll use to compose a new graph
        # after the iteration, since the graph size can't fluctuate as we iterate through
        temp_graph = nx.Graph()
        node = CoherenceNode(word[0], word[1], word[2])
        for n in prev_graph.nodes():
            if n.vector*node.vector >= 20:
                temp_graph.add_edge(node, n, weight=n.vector*node.vector)
        G = nx.compose(G,temp_graph)
        temp_prev_graph.add_node(node)
        # add the node. If it was already added, it won't be added again
        G.add_node(node)

# %%
# G.prune_max_depth(1, G.get_node_by_id(0)[0])

# %%
for path in nx.all_simple_paths(G, source=G.get_node_by_id(1)[0], target=G.get_node_by_id(4)[0]):
    print(path)
# Out:
# [Node(1, 'world', 6), Node(4, 'work', 5)]

# %%
G.get_all_paths_to_node(G.get_node_by_id(4)[0])
# Out:
# [[Node(4, 'work', 5), Node(0, 'hello', 5)],
#  [Node(4, 'work', 5), Node(1, 'world', 6)],
#  [Node(4, 'work', 5), Node(2, 'earth', 7)],
#  [Node(4, 'work', 5), Node(2, 'earth', 7), Node(3, 'school', 3)],
#  [Node(4, 'work', 5), Node(5, 'assignments', 6)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5),
#   Node(5, 'assignments', 6)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5),
#   Node(5, 'assignments', 6)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5),
#   Node(5, 'assignments', 6)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6),
#   Node(6, 'deadline', 4)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5),
#   Node(6, 'deadline', 4)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6),
#   Node(6, 'deadline', 4)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5),
#   Node(6, 'deadline', 4)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5),
#   Node(6, 'deadline', 4)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6),
#   Node(6, 'deadline', 4)],
#  [Node(4, 'work', 5), Node(6, 'deadline', 4)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6),
#   Node(6, 'deadline', 4)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5),
#   Node(6, 'deadline', 4)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5),
#   Node(6, 'deadline', 4)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6),
#   Node(6, 'deadline', 4)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6),
#   Node(6, 'deadline', 4)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5),
#   Node(6, 'deadline', 4)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5),
#   Node(8, 'midterms', 5)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5),
#   Node(8, 'midterms', 5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5),
#   Node(8, 'midterms', 5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5)],
#  [Node(4, 'work', 5), Node(8, 'midterms', 5)],
#  [Node(4, 'work', 5), Node(5, 'assignments', 6), Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5), Node(8, 'midterms', 5), Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6)],
#  [Node(4, 'work', 5), Node(5, 'assignments', 6), Node(10, 'math', 6)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6)],
#  [Node(4, 'work', 5), Node(6, 'deadline', 4), Node(10, 'math', 6)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6)],
#  [Node(4, 'work', 5), Node(8, 'midterms', 5), Node(10, 'math', 6)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5)],
#  [Node(4, 'work', 5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5)],
#  [Node(4, 'work', 5), Node(5, 'assignments', 6), Node(11, 'science', 6.5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6),
#   Node(9, 'gym', 4.5),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5)],
#  [Node(4, 'work', 5),
#   Node(6, 'deadline', 4),
#   Node(10, 'math', 6),
#   Node(8, 'midterms', 5),
#   Node(11, 'science', 6.5)],
#  [Node(4, 'work', 5), Node(6, 'deadline', 4), Node(11, 'science', 6.5)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5),
#   Node(5, 'assignments', 6),
#   Node(10, 'math', 6),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(9, 'gym', 4.5),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6),
#   Node(5, 'assignments', 6),
#   Node(11, 'science', 6.5)],
#  [Node(4, 'work', 5),
#   Node(8, 'midterms', 5),
#   Node(10, 'math', 6),
#   Node(6, 'deadline', 4),
#   Node(11, 'science', 6.5)],
#  [Node(4, 'work', 5), Node(8, 'midterms', 5), Node(11, 'science', 6.5)]]

# %%
repr(G.get_node_by_id(0))
# Out:
# "(Node(0, 'hello', 5), AtlasView({Node(4, 'work', 5): {'weight': 25}}))"

# %%
G.nodes
# Out:
# NodeView((Node(0, 'hello', 5), Node(1, 'world', 6), Node(2, 'earth', 7), Node(3, 'school', 3), Node(4, 'work', 5), Node(5, 'assignments', 6), Node(6, 'deadline', 4), Node(7, 'lazy', 2), Node(8, 'midterms', 5), Node(9, 'gym', 4.5), Node(10, 'math', 6), Node(11, 'science', 6.5), Node(12, 'world', 2)))

# %%
nx.draw_shell(G, with_labels = True)

# %%
node, neighbors = G.get_node("hello")

repr(node)
# Out:
# "Node('hello', 5)"

# %%
for n in neighbors:
    print(repr(n))
# Out:
# Node('earth', 7)
# Node('science', 6.5)

# %%
for n in G.edges:
    print(n[0].word, n[1].word)
# Out:
# hello earth
# hello science
# world earth
# world assignments
# world math
# world science
# earth work
# earth assignments
# earth midterms
# earth gym
# earth math
# earth science
# work science
# assignments math
# assignments science
# midterms science
# math science

# %%
for n, nbrs in G.adj.items():
    for nbr, eattr in nbrs.items():
        print(eattr)
        wt = eattr['weight']
        if wt > 0.5: print(f"({n.word}, {nbr.word}, {wt})")
# Out:
# {'weight': 35}
# (hello, earth, 35)
# {'weight': 32.5}
# (hello, science, 32.5)
# {'weight': 42}
# (world, earth, 42)
# {'weight': 36}
# (world, assignments, 36)
# {'weight': 36}
# (world, math, 36)
# {'weight': 39.0}
# (world, science, 39.0)
# {'weight': 35}
# (earth, hello, 35)
# {'weight': 42}
# (earth, world, 42)
# {'weight': 35}
# (earth, work, 35)
# {'weight': 42}
# (earth, assignments, 42)
# {'weight': 35}
# (earth, midterms, 35)
# {'weight': 31.5}
# (earth, gym, 31.5)
# {'weight': 42}
# (earth, math, 42)
# {'weight': 45.5}
# (earth, science, 45.5)
# {'weight': 35}
# (work, earth, 35)
# {'weight': 32.5}
# (work, science, 32.5)
# {'weight': 36}
# (assignments, world, 36)
# {'weight': 42}
# (assignments, earth, 42)
# {'weight': 36}
# (assignments, math, 36)
# {'weight': 39.0}
# (assignments, science, 39.0)
# {'weight': 35}
# (midterms, earth, 35)
# {'weight': 32.5}
# (midterms, science, 32.5)
# {'weight': 31.5}
# (gym, earth, 31.5)
# {'weight': 36}
# (math, world, 36)
# {'weight': 42}
# (math, earth, 42)
# {'weight': 36}
# (math, assignments, 36)
# {'weight': 39.0}
# (math, science, 39.0)
# {'weight': 32.5}
# (science, hello, 32.5)
# {'weight': 39.0}
# (science, world, 39.0)
# {'weight': 45.5}
# (science, earth, 45.5)
# {'weight': 32.5}
# (science, work, 32.5)
# {'weight': 39.0}
# (science, assignments, 39.0)
# {'weight': 32.5}
# (science, midterms, 32.5)
# {'weight': 39.0}
# (science, math, 39.0)
